# %%
import pandas as pd
import numpy as np
import scipy.stats as st
import matplotlib.pyplot as plt

# %%
nba_data = pd.read_csv("C:/Users/agp07/Project_group_10/Datasets/all_seasons.csv")
nba_data
# Out:
#        Unnamed: 0          player_name team_abbreviation   age  player_height  \
# 0               0        Travis Knight               LAL  22.0         213.36
# 1               1            Matt Fish               MIA  27.0         210.82
# 2               2         Matt Bullard               HOU  30.0         208.28
# 3               3         Marty Conlon               BOS  29.0         210.82
# 4               4      Martin Muursepp               DAL  22.0         205.74
# ...           ...                  ...               ...   ...            ...
# 11695       11695  Matthew Dellavedova               CLE  30.0         190.50
# 11696       11696     Maurice Harkless               SAC  28.0         200.66
# 11697       11697            Max Strus               MIA  25.0         195.58
# 11698       11698    Marcus Morris Sr.               LAC  31.0         203.20
# 11699       11699         Aaron Gordon               DEN  25.0         203.20
#
#        player_weight                          college    country draft_year  \
# 0         106.594120                      Connecticut        USA       1996
# 1         106.594120        North Carolina-Wilmington        USA       1992
# 2         106.594120                             Iowa        USA  Undrafted
# 3         111.130040                       Providence        USA  Undrafted
# 4         106.594120                             None        USA       1996
# ...              ...                              ...        ...        ...
# 11695      90.718400  St.Mary's College of California  Australia  Undrafted
# 11696      99.790240                       St. John's        USA       2012
# 11697      97.522280                           DePaul        USA  Undrafted
# 11698      98.883056                           Kansas        USA       2011
# 11699     106.594120                          Arizona        USA       2014
#
#       draft_round  ...   pts  reb  ast  net_rating  oreb_pct  dreb_pct  \
# 0               1  ...   4.8  4.5  0.5         6.2     0.127     0.182
# 1               2  ...   0.3  0.8  0.0       -15.1     0.143     0.267
# 2       Undrafted  ...   4.5  1.6  0.9         0.9     0.016     0.115
# 3       Undrafted  ...   7.8  4.4  1.4        -9.0     0.083     0.152
# 4               1  ...   3.7  1.6  0.5       -14.5     0.109     0.118
# ...           ...  ...   ...  ...  ...         ...       ...       ...
# 11695   Undrafted  ...   2.8  1.8  4.5        -3.1     0.029     0.085
# 11696           1  ...   5.2  2.4  1.2        -2.9     0.017     0.097
# 11697   Undrafted  ...   6.1  1.1  0.6        -4.2     0.011     0.073
# 11698           1  ...  13.4  4.1  1.0         4.2     0.025     0.133
# 11699           1  ...  12.4  5.7  3.2         2.1     0.055     0.150
#
#        usg_pct  ts_pct  ast_pct   season
# 0        0.142   0.536    0.052  1996-97
# 1        0.265   0.333    0.000  1996-97
# 2        0.151   0.535    0.099  1996-97
# 3        0.167   0.542    0.101  1996-97
# 4        0.233   0.482    0.114  1996-97
# ...        ...     ...      ...      ...
# 11695    0.125   0.312    0.337  2020-21
# 11696    0.114   0.527    0.071  2020-21
# 11697    0.179   0.597    0.074  2020-21
# 11698    0.194   0.614    0.056  2020-21
# 11699    0.204   0.547    0.165  2020-21
#
# [11700 rows x 22 columns]

# %% [markdown]
# # Top players in each season:

# %%
# Top players in each season and the points they have scored, rebounds and ts_pct (shooting efficiency of player that takes
# 2 and 3 point shots)
top_players = nba_data[["player_name", "pts", "season","reb", "ts_pct", "player_height", "player_weight", "country"]]
players_by_season = top_players.loc[top_players.groupby(top_players["season"])["pts"].idxmax()]
players_by_season
# Out:
#              player_name   pts   season   reb  ts_pct  player_height  \
# 47        Michael Jordan  29.6  1996-97   5.9   0.567         198.12
# 854       Michael Jordan  28.7  1997-98   5.8   0.533         198.12
# 1009       Allen Iverson  26.8  1998-99   4.9   0.508         182.88
# 1518    Shaquille O'Neal  29.7  1999-00  13.6   0.578         215.90
# 2021       Allen Iverson  31.1  2000-01   3.8   0.518         182.88
# 2631       Allen Iverson  31.4  2001-02   4.5   0.489         182.88
# 2747       Tracy McGrady  32.1  2002-03   6.5   0.564         203.20
# 3276       Tracy McGrady  28.0  2003-04   6.0   0.526         203.20
# 3816       Allen Iverson  30.7  2004-05   4.0   0.532         182.88
# 4348         Kobe Bryant  35.4  2005-06   5.3   0.559         198.12
# 4835         Kobe Bryant  31.6  2006-07   5.7   0.580         198.12
# 5084        LeBron James  30.0  2007-08   7.9   0.568         203.20
# 5742         Dwyane Wade  30.2  2008-09   5.0   0.574         193.04
# 5982        Kevin Durant  30.1  2009-10   7.6   0.607         205.74
# 6285        Kevin Durant  27.7  2010-11   6.8   0.589         205.74
# 7140        Kevin Durant  28.0  2011-12   8.0   0.610         205.74
# 7441     Carmelo Anthony  28.7  2012-13   6.9   0.560         203.20
# 7952        Kevin Durant  32.0  2013-14   7.4   0.635         205.74
# 8267   Russell Westbrook  28.1  2014-15   7.3   0.536         190.50
# 8931       Stephen Curry  30.1  2015-16   5.4   0.669         190.50
# 9305   Russell Westbrook  31.6  2016-17  10.7   0.554         190.50
# 9573        James Harden  30.4  2017-18   5.4   0.619         195.58
# 10507       James Harden  36.1  2018-19   6.6   0.616         195.58
# 10750       James Harden  34.3  2019-20   6.6   0.626         195.58
# 11535      Stephen Curry  32.0  2020-21   5.5   0.655         190.50
#
#        player_weight country
# 47         97.975872     USA
# 854        97.975872     USA
# 1009       74.842680     USA
# 1518      142.881480     USA
# 2021       74.842680     USA
# 2631       74.842680     USA
# 2747       95.254320     USA
# 3276       95.254320     USA
# 3816       74.842680     USA
# 4348       99.790240     USA
# 4835       99.790240     USA
# 5084      113.398000     USA
# 5742       97.975872     USA
# 5982      104.326160     USA
# 6285      104.326160     USA
# 7140      106.594120     USA
# 7441      104.326160     USA
# 7952      108.862080     USA
# 8267       90.718400     USA
# 8931       86.182480     USA
# 9305       90.718400     USA
# 9573       99.790240     USA
# 10507      99.790240     USA
# 10750      99.790240     USA
# 11535      83.914520     USA

# %%
# Finding correlation and regression in between Ave_height and Ave_weight
Ave_hgt = players_by_season["player_height"]
Ave_wgt = players_by_season["player_weight"]
correlation = st.pearsonr(Ave_hgt, Ave_wgt)
print(f'The correlation between player height and weight is {round(correlation[0],2)}')
# Out:
# The correlation between player height and weight is 0.91

# %%
from scipy.stats import linregress

# %%
(slope, intercept, rvalue, pvalue, stderr)= linregress(Ave_hgt, Ave_wgt)
regress_values = Ave_hgt * slope + intercept

plt.scatter(Ave_hgt, Ave_wgt, color="b", alpha=0.5)
plt.plot(Ave_hgt, regress_values, color='red')
plt.xlabel("Ave_hgt")
plt.ylabel("Ave_wgt")
plt.title("Players height vs. weight")
plt.savefig("C:/Users/agp07/OneDrive/Pictures/Saved 1 Pictures")
plt.show()

# %% [markdown]
# # Top 5 players in all season:

# %%
top_players = nba_data[["player_name", "pts", "season","reb", "ts_pct", "player_height", "player_weight"]]
top_dogs = top_players[top_players["pts"] > 32.0 ]
top_dogs
# Out:
#          player_name   pts   season  reb  ts_pct  player_height  player_weight
# 2747   Tracy McGrady  32.1  2002-03  6.5   0.564         203.20       95.25432
# 4007   Allen Iverson  33.0  2005-06  3.2   0.543         182.88       74.84268
# 4348     Kobe Bryant  35.4  2005-06  5.3   0.559         198.12       99.79024
# 10507   James Harden  36.1  2018-19  6.6   0.616         195.58       99.79024
# 10750   James Harden  34.3  2019-20  6.6   0.626         195.58       99.79024

# %%
players_by_countries = nba_data["country"].unique()
players_by_countries
# Out:
# array(['USA', 'Jamaica', 'Serbia and Montenegro', 'Ukraine', 'Canada',
#        'Croatia', 'Lithuania', 'Nigeria', 'Congo',
#        'St. Vincent & Grenadines', 'US Virgin Islands', 'France',
#        'Slovenia', 'Dominican Republic', 'Germany', 'Georgia',
#        'New Zealand', 'Belize', 'England', 'Argentina',
#        'U.S. Virgin Islands', 'Greece', 'Senegal', 'China', 'Turkey',
#        'Finland', 'Mali', 'Puerto Rico', 'Mexico', 'Yugoslavia', 'Serbia',
#        'Spain', 'Venezuela', 'Haiti', 'Russia', 'Ireland', 'Brazil',
#        'Scotland', 'Poland', 'Netherlands', 'Czech Republic',
#        'Montenegro', 'United Kingdom', 'Democratic Republic of the Congo',
#        'Latvia', 'South Korea', 'Uruguay', 'Sudan (UK)', 'Australia',
#        'USSR', 'Italy', 'Switzerland', 'Gabon', 'Cameroon', 'Iran',
#        'Israel', 'Sweden', 'Tanzania', 'Panama', 'Bosnia',
#        'Great Britain', 'Macedonia', 'Bosnia & Herzegovina', 'Cabo Verde',
#        'Tunisia', 'South Sudan', 'Bahamas', 'Ghana', 'Austria',
#        'Bosnia and Herzegovina', 'Egypt', 'Japan', 'Trinidad and Tobago',
#        'DRC', 'Sudan', 'Angola', 'Saint Lucia', 'Republic of the Congo',
#        'Guinea'], dtype=object)

# %%
country_count = nba_data["country"].value_counts()
final_data = country_count.head()
final_data
# Out:
# USA          9836
# France        167
# Canada        161
# Brazil         83
# Australia      83
# Name: country, dtype: int64

# %%
labels = ["USA", "France", "Canada", "Brazil", "Australia"]

# The values of each section of the pie chart
sizes = ["1000", "167", "161", "83", "83"]

# The colors of each section of the pie chart
colors = ["red", "orange", "lightcoral", "lightskyblue", "blue"]

# Tells matplotlib to separate the "Humans" section from the others
explode = (0.1,0,0,0,0)

plt.pie(sizes, explode=explode, labels=labels, colors=colors,
        shadow=True, startangle=140)
plt.savefig("C:/Users/agp07/OneDrive/Pictures/Saved 2 Pictures")

# %%
plot_pandas = final_data.plot.bar(figsize=(5,4), color='b', alpha=0.5, fontsize = 11)
plt.xlabel("Countries")
plt.ylabel("Player Counts")
plt.title("Top 5 Countries of Players")
plt.ylim(0, max(final_data)+500)

def addlabels(x,y):
    for i in range(len(x)):
        plt.text(i,y[i],y[i])
if __name__ == '__main__':
    # creating data on which bar chart will be plot
    x = ["USA", "France", "Canada",
         "Brazil", "Australia"]
    y = [9836, 167, 161, 83,
         83]
    
    # making the bar chart on the data
    plt.bar(x, y)
    
    # calling the function to add value labels
    addlabels(x, y)
    plt.savefig("C:/Users/agp07/OneDrive/Pictures/Saved 3 Pictures")

    plt.show()

# %%
nba_data["team_abbreviation"].unique()
# Out:
# array(['LAL', 'MIA', 'HOU', 'BOS', 'DAL', 'TOR', 'CLE', 'GSW', 'IND',
#        'PHI', 'PHX', 'POR', 'LAC', 'CHH', 'SAC', 'CHI', 'NYK', 'DET',
#        'ORL', 'SEA', 'WAS', 'VAN', 'SAS', 'ATL', 'NJN', 'UTA', 'MIL',
#        'DEN', 'MIN', 'MEM', 'NOH', 'CHA', 'NOK', 'OKC', 'BKN', 'NOP'],
#       dtype=object)

# %%
# %matplotlib notebook

# %%
# Filter players with age, pts and player_name :
Players_by_age = nba_data[["player_name", "age", "pts"]]

youngest_pl = Players_by_age[Players_by_age["age"] > 41.0 ]
youngest_pl= youngest_pl.head()
youngest_pl
# Out:
#           player_name   age  pts
# 169     Robert Parish  43.0  3.7
# 3576     Kevin Willis  42.0  3.0
# 4840     Kevin Willis  44.0  2.4
# 5293  Dikembe Mutombo  42.0  3.0
# 5757  Dikembe Mutombo  43.0  1.8

# %%
oldest_player = Players_by_age[Players_by_age["age"] < 20 ]
oldest_player= oldest_player.head()
oldest_player
# Out:
#          player_name   age   pts
# 96       Kobe Bryant  18.0   7.6
# 221  Jermaine O'Neal  18.0   4.1
# 659  Jermaine O'Neal  19.0   4.5
# 743    Tracy McGrady  19.0   7.0
# 780      Kobe Bryant  19.0  15.4

# %%
age = [18, 20, 30, 40, 45]
young_pl_pts = youngest_pl["pts"]
old_pl_pts = oldest_player["pts"]

youngest_player_score = plt.plot(age, old_pl_pts, color="blue", marker='s', label='Youngest Player Score')
oldest_player_score = plt.plot(age, young_pl_pts, color="red", marker='s', label='Oldest Player Score')
plt.xlabel("Age(Year)")
plt.ylabel("Player Points")
plt.title("Players Age vs. Points")
plt.grid()
plt.show()
plt.savefig("C:/Users/agp07/OneDrive/Pictures/Saved 4 Pictures")
# Out:
# <img src="data:image/png;base64,..." width="639.999974568686">
